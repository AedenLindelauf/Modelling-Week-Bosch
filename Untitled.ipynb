# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import ipywidgets as widgets

# %%
t = np.linspace(1, 10, 100)

y = (t -10*t**2 + 5*t**7) / (t**3 + t**10)

# %%
plt.plot(t,y)

# %%
def func(x, *coeffs):
    num = sum( [coeffs[i] * x**i for i in range(degree_num + 1)] )
    den = sum( [coeffs[i+(degree_num+1)] * x**i for i in range(degree_den+1)] )
    return num / den

# %%
from sympy import Symbol

x = Symbol("x")
degree_num = 1
degree_den = 3
coeffs = [1,2, 1,1,1,1]
func(x, *coeffs)
# Out:
# (2*x + 1)/(x**3 + x**2 + x + 1)

# %%
slider = widgets.IntSlider(
    value=7,
    min=0,
    max=10,
    step=1,
    description='Test:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)
slider
# Out:
# IntSlider(value=7, continuous_update=False, description='Test:', max=10)

# %%
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.curve_fit.html

fig, ax = plt.figure( figsize=(6,6) )
plt.show()

slider = widgets.IntSlider(value=0, min=0, max=10, step=1);

# callback function for the slider widget
def update(change):
    ax.imshow(t, func(t, *popt), 'g--', label='fit')
    fig.canvas.draw()

p0 = np.ones(degree_num+degree_den+2)

popt, pcov = curve_fit(func, t, y, p0=p0)

plt.plot(t, y, 'b-', label='data')
plt.plot(t, func(t, *popt), 'g--', label='fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# connect update function to slider widget using the .observe() method, observing changes in value attribute
slider.observe(update, 'value')
slider
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 # https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.curve_fit.html
# ----> 3 fig, ax = plt.figure( figsize=(6,6) )
#       4 plt.show()
#       6 slider = widgets.IntSlider(value=0, min=0, max=10, step=1);
#
# TypeError: cannot unpack non-iterable Figure object
